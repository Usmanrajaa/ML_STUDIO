# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/student-performance-multiple-linear-regression/Student_Performance.csv

# %%
import numpy as np

# %%
import pandas as pd

# %%
np.random.seed(42)
x1=np.random.uniform(1,10,50)

# %%
y1=30+10*x1+np.random.normal(0,5,50)

# %%
import matplotlib.pyplot as plt

# %%
x1
# Out:
# array([4.37086107, 9.55642876, 7.58794548, 6.38792636, 2.40416776,
#        2.40395068, 1.52275251, 8.79558531, 6.41003511, 7.3726532 ,
#        1.18526045, 9.72918867, 8.49198377, 2.911052  , 2.6364247 ,
#        2.65064059, 3.73818019, 5.72280788, 4.88750517, 3.62106226,
#        6.50667605, 2.25544475, 3.62930184, 4.29725659, 5.10462986,
#        8.06658365, 2.79706404, 5.62810995, 6.33173112, 1.41805371,
#        6.46790367, 2.53471711, 1.58546434, 9.53996984, 9.6906883 ,
#        8.27557613, 3.74152392, 1.87904903, 7.15809724, 4.96137244,
#        2.09834411, 5.45659219, 1.30949669, 9.18388362, 3.32901983,
#        6.96270056, 3.80539968, 5.68061219, 5.92039251, 2.6636901 ])

# %%
y1
# Out:
# array([ 77.4009436 , 126.42112898, 105.30121335,  92.3737451 ,
#         46.64906769,  50.44028579,  42.92433124, 123.24146425,
#         95.8184425 ,  94.91133122,  43.47302433, 125.36647529,
#        111.53522767,  62.16890141,  61.51924466,  61.16280648,
#         63.18571425,  85.68201697,  80.53136883,  71.08834825,
#         92.67088934,  51.62615258,  60.7613435 ,  66.99153278,
#         85.10892769, 117.44703667,  57.61058979,  91.29876395,
#         95.12549132,  40.95493837,  96.4860147 ,  63.03735396,
#         45.67551317, 133.22291663, 113.80815746, 116.86527385,
#         67.85047457,  47.29545351, 102.03977627,  69.67587986,
#         49.8850817 ,  86.35148477,  50.48443712, 119.2474851 ,
#         59.24773033,  97.11822037,  72.63100744,  88.44987745,
#         86.55512412,  59.20323816])

# %%
plt.plot(x1)

# %%
plt.plot(y1)

# %%
data=pd.DataFrame({"x1":x1,"y1":y1})

# %%
data
# Out:
#           x1          y1
# 0   4.370861   77.400944
# 1   9.556429  126.421129
# 2   7.587945  105.301213
# 3   6.387926   92.373745
# 4   2.404168   46.649068
# 5   2.403951   50.440286
# 6   1.522753   42.924331
# 7   8.795585  123.241464
# 8   6.410035   95.818443
# 9   7.372653   94.911331
# 10  1.185260   43.473024
# 11  9.729189  125.366475
# 12  8.491984  111.535228
# 13  2.911052   62.168901
# 14  2.636425   61.519245
# 15  2.650641   61.162806
# 16  3.738180   63.185714
# 17  5.722808   85.682017
# 18  4.887505   80.531369
# 19  3.621062   71.088348
# 20  6.506676   92.670889
# 21  2.255445   51.626153
# 22  3.629302   60.761343
# 23  4.297257   66.991533
# 24  5.104630   85.108928
# 25  8.066584  117.447037
# 26  2.797064   57.610590
# 27  5.628110   91.298764
# 28  6.331731   95.125491
# 29  1.418054   40.954938
# 30  6.467904   96.486015
# 31  2.534717   63.037354
# 32  1.585464   45.675513
# 33  9.539970  133.222917
# 34  9.690688  113.808157
# 35  8.275576  116.865274
# ...

# %%
plt.figure(figsize=(10,10))
plt.scatter(data["x1"],data["y1"])
plt.title("x1 vs y1")
plt.xlabel("x1")
plt.ylabel("y1")
# Out:
# Text(0, 0.5, 'y1')

# %%
x1_mean=data["x1"].mean()

# %%
x1_mean
# Out:
# 5.01331513953035

# %%
y1_mean=data["y1"].mean()

# %%
y1_mean
# Out:
# 80.11842496796899

# %%
y1
# Out:
# array([ 77.4009436 , 126.42112898, 105.30121335,  92.3737451 ,
#         46.64906769,  50.44028579,  42.92433124, 123.24146425,
#         95.8184425 ,  94.91133122,  43.47302433, 125.36647529,
#        111.53522767,  62.16890141,  61.51924466,  61.16280648,
#         63.18571425,  85.68201697,  80.53136883,  71.08834825,
#         92.67088934,  51.62615258,  60.7613435 ,  66.99153278,
#         85.10892769, 117.44703667,  57.61058979,  91.29876395,
#         95.12549132,  40.95493837,  96.4860147 ,  63.03735396,
#         45.67551317, 133.22291663, 113.80815746, 116.86527385,
#         67.85047457,  47.29545351, 102.03977627,  69.67587986,
#         49.8850817 ,  86.35148477,  50.48443712, 119.2474851 ,
#         59.24773033,  97.11822037,  72.63100744,  88.44987745,
#         86.55512412,  59.20323816])

# %%
covariance=((data["x1"]-x1_mean)*(data["y1"]-y1_mean)).sum()

# %%
covariance
# Out:
# 3271.1543647340095

# %%
variance=((data["x1"]-x1_mean)**2).sum()

# %%
variance
# Out:
# 331.2269566149596

# %%
m=covariance/variance

# %%
m
# Out:
# 9.875870002140612

# %%
c=y1_mean-m*x1_mean

# %%
c
# Out:
# 30.60757637020383

# %%
from sklearn.linear_model import LinearRegression

X=data["x1"].values.reshape(-1,1)
Y=data["y1"].values
model=LinearRegression()
model.fit(X,Y)
model.coef_[0]

model.intercept_
# Out:
# 30.607576370203795

# %%
test_data=np.array([3,4,4.37086107]).reshape(-1,1)
model.predict(test_data)
# Out:
# array([60.23518638, 70.11105638, 73.77363209])

# %%
X=data["x1"].values.reshape(-1,1)

# %%
from sklearn.metrics import mean_absolute_error
y_pred=model.predict(X)

# %%
y_pred
# Out:
# array([ 73.77363209, 124.98562447, 105.54513948,  93.69390666,
#         54.35082467,  54.34868081,  45.6460822 , 117.4716335 ,
#         93.91224978, 103.41894095,  42.31305448, 126.6917789 ,
#        114.47330412,  59.35674745,  56.64456403,  56.78495825,
#         67.52535794,  87.12528309,  78.87594204,  66.36871654,
#         94.86666321,  52.88205548,  66.45008951,  73.04672382,
#         81.02023726, 110.27210788,  58.23101721,  86.19005855,
#         93.1389298 ,  44.61209051,  94.48375217,  55.64011307,
#         46.26541605, 124.82307829, 126.31155423, 112.33609045,
#         67.55838024,  49.16482028, 101.30001416,  79.60544566,
#         51.33055006,  84.4961715 ,  43.53999545, 121.3064171 ,
#         63.48454349,  99.37030196,  68.18920896,  86.7085639 ,
#         89.0766032 ,  56.91383352])

# %%
mean_absolute_error(Y,y_pred)
# Out:
# 3.653203600917303

# %%
from sklearn.metrics import mean_squared_error

# %%
mse=mean_squared_error(Y,y_pred)

# %%
rmse=np.sqrt(mse)

# %%
rmse
# Out:
# 4.5361634222895

# %%
plt.figure(figsize=(10,10))
plt.scatter(data["x1"],data["y1"])
plt.plot(data["x1"],y_pred,color="red")
plt.title("x1 vs y1")
plt.xlabel("x1")
plt.ylabel("y1")
# Out:
# Text(0, 0.5, 'y1')

# %%
residuals=Y-y_pred

# %%
residuals
# Out:
# array([  3.6273115 ,   1.43550452,  -0.24392613,  -1.32016156,
#         -7.70175698,  -3.90839502,  -2.72175096,   5.76983075,
#          1.90619272,  -8.50760972,   1.15996985,  -1.3253036 ,
#         -2.93807644,   2.81215395,   4.87468064,   4.37784824,
#         -4.33964369,  -1.44326612,   1.65542679,   4.71963172,
#         -2.19577387,  -1.2559029 ,  -5.68874601,  -6.05519104,
#          4.08869044,   7.17492878,  -0.62042742,   5.10870539,
#          1.98656153,  -3.65715214,   2.00226253,   7.39724089,
#         -0.58990288,   8.39983834, -12.50339677,   4.5291834 ,
#          0.29209433,  -1.86936677,   0.73976211,  -9.92956579,
#         -1.44546836,   1.85531326,   6.94444167,  -2.05893201,
#         -4.23681316,  -2.25208158,   4.44179847,   1.74131356,
#         -2.52147908,   2.28940464])

# %%
import seaborn as sns
from scipy import stats
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.scatterplot(residuals)

plt.figure(figsize=(10,5))
plt.subplot(1,2,2)
stats.probplot(residuals,plot=plt)
# Out:
# ((array([-2.20385432, -1.83293478, -1.61402323, -1.45296849, -1.32267759,
#          -1.21163342, -1.113805  , -1.02561527, -0.94475674, -0.86964726,
#          -0.79915021, -0.73241807, -0.66879925, -0.6077796 , -0.54894415,
#          -0.49195112, -0.43651377, -0.38238727, -0.32935914, -0.27724191,
#          -0.2258675 , -0.17508277, -0.12474591, -0.07472335, -0.02488719,
#           0.02488719,  0.07472335,  0.12474591,  0.17508277,  0.2258675 ,
#           0.27724191,  0.32935914,  0.38238727,  0.43651377,  0.49195112,
#           0.54894415,  0.6077796 ,  0.66879925,  0.73241807,  0.79915021,
#           0.86964726,  0.94475674,  1.02561527,  1.113805  ,  1.21163342,
#           1.32267759,  1.45296849,  1.61402323,  1.83293478,  2.20385432]),
#   array([-12.50339677,  -9.92956579,  -8.50760972,  -7.70175698,
#           -6.05519104,  -5.68874601,  -4.33964369,  -4.23681316,
#           -3.90839502,  -3.65715214,  -2.93807644,  -2.72175096,
# ...

# %% [markdown]
# # BIVARIATE

# %%
np.random.seed(42)

# %%
a1=np.random.randint(1,20,50)

# %%
a2=np.random.randint(1,50,50)

# %%
a3=30+20*a1+10*a2+np.random.normal(0,5,50)

# %%
df=pd.DataFrame({"x1":a1,"x2":a2,"x3":a3})

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(8,5))
ax1.scatter(df["x1"],df["x3"])
ax2.scatter(df["x2"],df["x3"])
ax1.set_xlabel("x1 vs x3")
ax2.set_xlabel("x2 vs x3")
# Out:
# Text(0.5, 0, 'x2 vs x3')

# %%
X=df[['x1','x2']]

# %%
Y=df['x3']

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X,Y)
print(model.intercept_)
print(model.coef_[0])
# Out:
# 28.66659031169081
# 20.19278369690725

# %%
Y_pred=model.predict(X)

# %%
mse=mean_squared_error(Y,Y_pred)

# %%
mae=mean_absolute_error(Y,Y_pred)

# %%
rmse=np.sqrt(mse)

# %%
from sklearn.metrics import r2_score

# %%
r2=r2_score(Y,Y_pred)

# %% [markdown]
# # MULTIVARIATE

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("nikhil7280/student-performance-multiple-linear-regression")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/student-performance-multiple-linear-regression

# %%
data=pd.read_csv("/kaggle/input/student-performance-multiple-linear-regression/Student_Performance.csv")

# %%
data
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
data.shape
# Out:
# (10000, 6)

# %%
data.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
data['Extracurricular Activities']=data['Extracurricular Activities'].map({'Yes':1,'No':0})

# %%
data
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
# ...

# %%
x=data.drop('Performance Index',axis=1)

# %%
x
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
# ...

# %%
y=data['Performance Index']

# %%
from sklearn.model_selection import train_test_split
X_train,x_test,Y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9889832909573145

# %%
import seaborn as sns

# %%
data_matrix=data.corr()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data_matrix,annot=True,cmap='viridis')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20,10))
sns.boxplot(data.drop('Performance Index',axis=1))
# Out:
# <Axes: >

# %% [markdown]
# # polynomia regression

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly=PolynomialFeatures(degree=2)

# %%
X_poly=poly.fit_transform(X_train)

# %%
X_poly
# Out:
# array([[ 1.,  5., 49., ..., 49., 35., 25.],
#        [ 1.,  2., 48., ..., 49., 42., 36.],
#        [ 1.,  2., 81., ..., 49., 14.,  4.],
#        ...,
#        [ 1.,  9., 48., ..., 49., 42., 36.],
#        [ 1.,  1., 47., ..., 81.,  0.,  0.],
#        [ 1.,  2., 46., ..., 36., 36., 36.]])

# %%
model=LinearRegression()

# %%
model.fit(X_poly,Y_train)
# Out:
# LinearRegression()

# %%
X_test_poly=poly.fit_transform(x_test)

# %%
model.predict(X_test_poly)
# Out:
# array([54.69216675, 22.62422158, 47.92480882, ..., 16.63506145,
#        63.3585401 , 45.92414491])

# %%
model.predict(X_poly)
# Out:
# array([34.40202789, 25.61314223, 57.92622915, ..., 44.97375466,
#        20.96464792, 22.59105086])

# %% [markdown]
# # Ridge & Lasso regression

# %%
from sklearn.linear_model import
